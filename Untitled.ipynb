# %%
# !python ./data_generation/maps_gen.py --field_size 128 --dencity 0.2 --obstacles_num 5 --indent 3 --dataset_size 500 --tasks_num 5 --theta 1
# Out:
# random_shapes: False

# %%
# !python3 ./data_generation/ppms_gen.py --dataset_folder ./size_128/20_den_non_theta/
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-eq9dmuza because the default path (/home/user/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# ...

# %%
# !python3 ./train.py --img_size 128 --channels 1 --num_classes 1 --dataset_dir ./size_128/20_den/ --results_dir ./size_128/20_den_results/ --batch_size 32 --epoch_count 1 --number_of_epochs 100
# Out:
# ===> Building models
# learning rate = 0.0002000
# learning rate = 0.0002000
# ===> Avg. PSNR: 8.8033 dB
# learning rate = 0.0002000
# learning rate = 0.0002000
# ===> Avg. PSNR: 9.6807 dB
# learning rate = 0.0002000
# learning rate = 0.0002000
# ===> Avg. PSNR: 10.5883 dB
# learning rate = 0.0002000
# learning rate = 0.0002000
# ===> Avg. PSNR: 11.1463 dB
# learning rate = 0.0002000
# learning rate = 0.0002000
# ===> Avg. PSNR: 11.6309 dB
# learning rate = 0.0002000
# learning rate = 0.0002000
# ===> Avg. PSNR: 11.5230 dB
# learning rate = 0.0002000
# learning rate = 0.0002000
# ===> Avg. PSNR: 11.5565 dB
# learning rate = 0.0002000
# learning rate = 0.0002000
# ===> Avg. PSNR: 11.9122 dB
# learning rate = 0.0002000
# learning rate = 0.0002000
# ===> Avg. PSNR: 12.6575 dB
# learning rate = 0.0002000
# learning rate = 0.0002000
# ===> Avg. PSNR: 12.0269 dB
# learning rate = 0.0002000
# learning rate = 0.0002000
# ===> Avg. PSNR: 12.3209 dB
# learning rate = 0.0002000
# ...
